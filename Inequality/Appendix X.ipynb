# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imports-&amp;-Function-Definitions" data-toc-modified-id="Imports-&amp;-Function-Definitions-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imports &amp; Function Definitions</a></span><ul class="toc-item"><li><span><a href="#Main-Analysis-Functions" data-toc-modified-id="Main-Analysis-Functions-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Main Analysis Functions</a></span></li></ul></li><li><span><a href="#Raw-Data" data-toc-modified-id="Raw-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Raw Data</a></span><ul class="toc-item"><li><span><a href="#Main-Data-Sources" data-toc-modified-id="Main-Data-Sources-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Main Data Sources</a></span></li><li><span><a href="#Alternative-Data-Sources" data-toc-modified-id="Alternative-Data-Sources-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Alternative Data Sources</a></span></li><li><span><a href="#Raw-Data-Manipulations" data-toc-modified-id="Raw-Data-Manipulations-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Raw Data Manipulations</a></span><ul class="toc-item"><li><span><a href="#Create-&quot;45-to-64&quot;-column-for-income" data-toc-modified-id="Create-&quot;45-to-64&quot;-column-for-income-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Create "45 to 64" column for income</a></span></li><li><span><a href="#Clean-Re-Formatted-SDMX-tables" data-toc-modified-id="Clean-Re-Formatted-SDMX-tables-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Clean Re-Formatted SDMX tables</a></span><ul class="toc-item"><li><span><a href="#2001-Census" data-toc-modified-id="2001-Census-2.3.2.1"><span class="toc-item-num">2.3.2.1&nbsp;&nbsp;</span>2001 Census</a></span></li><li><span><a href="#2006-Census" data-toc-modified-id="2006-Census-2.3.2.2"><span class="toc-item-num">2.3.2.2&nbsp;&nbsp;</span>2006 Census</a></span></li><li><span><a href="#2011-Census" data-toc-modified-id="2011-Census-2.3.2.3"><span class="toc-item-num">2.3.2.3&nbsp;&nbsp;</span>2011 Census</a></span></li><li><span><a href="#2016-Census" data-toc-modified-id="2016-Census-2.3.2.4"><span class="toc-item-num">2.3.2.4&nbsp;&nbsp;</span>2016 Census</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Define-Variables" data-toc-modified-id="Define-Variables-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Define Variables</a></span><ul class="toc-item"><li><span><a href="#Join-City-&amp;-Health-Shapefiles" data-toc-modified-id="Join-City-&amp;-Health-Shapefiles-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Join City &amp; Health Shapefiles</a></span></li></ul></li><li><span><a href="#Run-Calculations" data-toc-modified-id="Run-Calculations-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Run Calculations</a></span><ul class="toc-item"><li><span><a href="#Prepare-Data-for-Analysis" data-toc-modified-id="Prepare-Data-for-Analysis-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Prepare Data for Analysis</a></span></li><li><span><a href="#Merge-Other-Datasets-(Food-Insec./Unemp./Education)" data-toc-modified-id="Merge-Other-Datasets-(Food-Insec./Unemp./Education)-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Merge Other Datasets (Food Insec./Unemp./Education)</a></span><ul class="toc-item"><li><span><a href="#Merge-with-Food-Insecurity" data-toc-modified-id="Merge-with-Food-Insecurity-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Merge with Food Insecurity</a></span></li><li><span><a href="#Merge-with-Unemployment" data-toc-modified-id="Merge-with-Unemployment-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Merge with Unemployment</a></span></li><li><span><a href="#Merge-with-Education" data-toc-modified-id="Merge-with-Education-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Merge with Education</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Imports & Function Definitions

# %%
import time, datetime, sys, os, numpy as np, pandas as pd, geopandas as gpd
import sqlalchemy
from difflib import SequenceMatcher
import seaborn as sns
import statsmodels.api as sm 
from scipy.stats import rv_discrete
import sqlite3 as db
from itertools import permutations, product, chain
from functools import reduce
import re
import matplotlib.pyplot as plt
import plotly.plotly as py
from copy import copy

from pyspark.sql import SparkSession


scriptDir = os.path.dirname(os.path.realpath(sys.argv[0]))   # get script directory

if sys.platform == 'linux':
    genDir ="/home/benmo/OneDrive/GitHub/DataPlayground"
else:
    try: 
        genDir = "D:/OneDrive/GitHub/DataPlayground" #get general functions path
        os.chdir(genDir)
    except: 
        genDir = "D:/benmo/OneDrive/GitHub/DataPlayground"
        os.chdir(genDir)

os.chdir(genDir)

from General import * # import custom 'general' functions

os.chdir(scriptDir)
# Out:
# /home/benmo/intelpython3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xb but this version of numpy is 0xa

# %%
# %load_ext rpy2.ipython
# %load_ext beakerx_magics.sql_magic
# %load_ext beakerx_magics.groovy_magic
# %load_ext beakerx_magics.scala_magic
# %load_ext beakerx_magics.java_magic

# %% [markdown]
# load R libraries:

# %%
# %%R
# lapply(list('ggplot2','SciencesPo', 'binsmooth'), require, character.only = TRUE)
# Out:
# /home/benmo/intelpython3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
#
# Loading required package: ggplot2
#
#
# /home/benmo/intelpython3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
#
# Loading required package: SciencesPo
#
#
# /home/benmo/intelpython3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
#
# SciencesPo 1.4.1
#
#
# /home/benmo/intelpython3/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
#
# Loading required package: binsmooth
# [[1]]
# [1] TRUE
#
# [[2]]
# [1] TRUE
#
# [[3]]
# [1] TRUE

# %% [markdown]
# ## Main Analysis Functions

# %%
similar = lambda a, b: SequenceMatcher(None, a, b).ratio()


def floatit(x, repl):    
    try:
        x = float(x)
    except:
        x = repl
    return x

get_prob = lambda x: list(map(lambda z, z_s=x: z/sum(z_s)*100,x))

idx = pd.IndexSlice


spark = SparkSession.builder.appName(
        'myspark').master("local[4]").config(
                "spark.ui.enabled","false").config(
                        "spark.driver.extraClassPath",
                        "/home/benmo/DB_drivers/sqlite-jdbc-3.16.1.jar").config(
                                "spark.executor.extraClassPath", 
                                "/home/benmo/DB_drivers/sqlite-jdbc-3.16.1.jar").getOrCreate()



def get_incDist(vals):
    # %R -n bins <- c(10000, 20000, 35000, 50000, 75000, 100000, NaN)
    vals = pd.Series(vals)
    # %R -i vals
    # %R -n hist <- splinebins(bins, vals)
    bins = %R seqi <- seq(0,299000,length=10000)
    cdf = %R cdf <- hist$splineCDF(seqi)
    prob = np.diff(cdf)
    bins = bins[1:]
    return rv_discrete(values=(bins, prob/sum(prob)))


def get_gini(data):
    try:
        data = pd.Series(data)
        # %R -i data gini <- Gini(data)
        gini = %R gini
        return gini[0]
    except:
        return None

def get_atkinson(data, eps=0.5):
    try:
        data = pd.Series(data)
        # %R -i eps
        # %R -i data atk <- Atkinson(data, epsilon=eps);
        atk = %R atk 
        return atk[0]
    except:
        return None

def get_palma(rv,data):
    try:
        ll = rv.ppf(0.4)
        ul = rv.ppf(0.9)
        
        return data[data > ul].sum() / data[data < ll].sum()
    except:
        return None

def closestIndex(x,c):
    temp = list(map(lambda x: similar(x,c), x))
    return temp.index(max(temp))


uniq = lambda x, y: x[y].unique()


tuple2str = lambda name: name if isinstance(name, tuple) ==False else reduce(lambda x, y:  str(x)
        .replace('.0','') + '_' + str(y).replace('.0',''), list(map(lambda xi: str(xi), name)))



def get_Healthx(hRegions, spark, i, j):
    health = spark.read.format("jdbc").option("url", 
                               "jdbc:sqlite:/home/benmo/Data/Databases/health.db").option(
                                       "dbtable", 'CCHS_Survey').load()
    
    healthx = health.select('*').where(((health.AGE == healthVars['age'][i]) & (health.HRPROF == healthVars['hrprof'][j])) & (
                    health.UNIT == healthVars['unit'][1])).toPandas()
                    
    healthx.Geographicalclassification = healthx.Geographicalclassification.apply(
            lambda x: x[:4])
                              
    return healthx



def get_incDistx(provinces, spark, i, j):
    incDist = spark.read.format("jdbc").option("url", 
                               "jdbc:sqlite:/home/benmo/Data/Databases/income.db").option(
                                       "dbtable", "incomeDist").load()

    incDistx = incDist.select(list(filter(lambda x: x not in['Vector', 'Coordinate'],
                                          incDist.columns))).where(incDist.AGE == incDistVars['age'][i]).toPandas() 
    incDistx = incDistx[incDistx.GEO.apply(lambda x: x not in provinces + ['Canada']) == True]
    incDistx.GEO = incDistx.GEO.apply(lambda x: x[:12] if x.find(',') >=12 else x[:x.find(',')])    #truncate city names for matching
    
    return incDistx

# %% [markdown]
# # Raw Data

# %% [markdown]
# ## Main Data Sources

# %% [markdown]
# __Income Data Source:__ http://www5.statcan.gc.ca/cansim/a26?lang=eng&retrLang=eng&id=1110008&&pattern=&stByVal=1&p1=1&p2=37&tabMode=dataTable&csid=
#
# __Location:__ /home/benmo/Data/Databases/income.db
#
# __CCHS Data Sources:__ http://www5.statcan.gc.ca/cansim/a26?lang=eng&retrLang=eng&id=1050547&&pattern=&stByVal=1&p1=1&p2=-1&tabMode=dataTable&csid
#
# http://www5.statcan.gc.ca/cansim/a26?lang=eng&retrLang=eng&id=1050547&&pattern=&stByVal=1&p1=1&p2=-1&tabMode=dataTable&csid=
#
# http://www5.statcan.gc.ca/cansim/a26?lang=eng&retrLang=eng&id=1090200&&pattern=&stByVal=1&p1=1&p2=-1&tabMode=dataTable&csid=
#
# http://www5.statcan.gc.ca/cansim/a26?lang=eng&retrLang=eng&id=1090300&&pattern=&stByVal=1&p1=1&p2=-1&tabMode=dataTable&csid=
#
# http://www5.statcan.gc.ca/cansim/a26?lang=eng&retrLang=eng&id=1090401&&pattern=&stByVal=1&p1=1&p2=-1&tabMode=dataTable&csid=
#
# http://www5.statcan.gc.ca/cansim/a26?lang=eng&retrLang=eng&id=1095304&tabMode=dataTable&p1=1&p2=-1&srchLan=-1&pattern=unemployment+health
#
# http://www5.statcan.gc.ca/cansim/a26?lang=eng&retrLang=eng&id=1095334&tabMode=dataTable&p1=1&p2=-1&srchLan=-1&pattern=unemployment+health
#
#
# __Location:__ /home/benmo/Data/Databases/health.db

# %% [markdown]
# ## Alternative Data Sources

# %% [markdown]
# * These data sources were used for gathering education and labor force information for Canadian cities in major census years
#
# * After converting SDMX data files 97-560-XCB2006025, 99-012-X2011042, 97F0017XCB2001040, and 98-400-X2016276 from SDMX (xml) to .csv format,
#     the structure files were uploaded to a MongoDB database for querying as shown below:

# %%
from pymongo import MongoClient
import pandas as pd

client = MongoClient()

mdb = client['Data']                   # Connect to appropriate database in MongoDB


"""____________ CREATE KEYS TO QUERY ON THE DATA COLUMNS______________"""
varList2001 = {'geo': 'CL_GEO', 
           'sex': 'CL_SEX', 
           'age': 'CL_AGE',
           'schatt': 'CL_ATTENDR',
           'educ': 'CL_HLOSR',
           'labor': 'CL_LFTAG'}

varList2006 = {'geo': 'CL_GEO', 
           'immyr': 'CL_YRIM', 
           'educ': 'CL_HCDD',
           'age': 'CL_AGE',
           'sex': 'CL_SEX',
           'studyloc': 'CL_LOC_STUDY',
           'labor': 'CL_DIM'}

varList2011 = {'geo': 'CL_GEO', 
           'immyr': 'CL_PERIMMB', 
           'studyloc': 'CL_LOC_STUDY',
           'age': 'CL_AGEGR5',
           'sex': 'CL_SEX',
           'educ': 'CL_HCDD',
           'labor': 'CL_DIM'}

varList2016 = {'geo' : 'CL_GEO', 
           'stem' : 'CL_CIP2011_STEM', 
           'educ' : 'CL_HCDD_14V', 
           'immSt' : 'CL_IMMDER',
           'age' : 'CL_AGEGR5',
           'sex' : 'CL_SEX',
           'minority' : 'CL_DVISMIN',
           'labor' : 'CL_DIM'}

varDict = {2001 : varList2001, 2006 : varList2006,
           2011 : varList2011, 2016 : varList2016} # Pack key lists to a dictionary object


dataKeysDict = {}
colsDict = {}

"""______________RUN MONGODB QUERIES AND EXTRACT NAMES FOR CODED VARIABLES___________"""
for yr in varDict.keys():
    dataKeysDict[yr] = {}
    colsDict[yr] = []
    docs = mdb['canadael{y}'.format(y=yr)]
    
    for key in varDict[yr].keys():
        pipeline = [
            {"$unwind": "$items"},
            {"$unwind": "$items.items"},
            {"$unwind": "$items.items.items"},
            {"$match": {"items.attrs.id": varDict[yr][key]}},
            {"$match": {"items.items.items.attrs.xml:lang": "en"}},
            {"$group": {"_id": {key: "$items.items.items.items",
            key + "id": "$items.items.attrs"}}}
            ]
        if key == 'geo':
            pipeline.pop(4) 
        
        temp = list(docs.aggregate(pipeline)) # collect values for coded varaibles w/ other unwanted queries
        
        temp = list(filter(lambda x: len(x['_id'])==2, temp))      # filter out unwanted data
        temp = list(filter(lambda x: len(x['_id'][key])==1, temp)) # filter out unwanted data
        temp = pd.DataFrame(list(map(lambda x: x['_id'],temp)))    # store as dataframe       
        temp[key] = temp[key].apply(lambda x: x[0])      
        temp[key + 'id'] = temp[key + 'id'].apply(lambda x: x['value'])
      
        dataKeysDict[yr][key] = temp         # dictionary object that holds all the coded information
        colsDict[yr].append(key)             # dictionary that holds the column names and preserves positioning

# %% [markdown]
# ## Raw Data Manipulations

# %% [markdown]
# As shown below, the income data does not contain a "45 to 64" age range:

# %%
"""_______________________HEALTH DATA_____________________________"""
health = spark.read.format("jdbc").option("url", 
                               "jdbc:sqlite:/home/benmo/Data/Databases/health.db").option(
                                       "dbtable", 'CCHS_Survey').load()
health.select('age').distinct().show()
# Out:
# +--------------------+
# |                 age|
# +--------------------+
# |      45 to 64 years|
# |Total, 12 years a...|
# |Total, 12 year an...|
# |      20 to 34 years|
# |   65 years and over|
# |Total, 12 years a...|
# |      12 to 19 years|
# |      35 to 44 years|
# +--------------------+

# %%
"""______________________INCOME DATA_______________________________"""
incDist = spark.read.format("jdbc").option("url", 
            "jdbc:sqlite:/home/benmo/Data/Databases/income.db").option(
                            "dbtable", "incomeDist").load()
incDist.select('age').distinct().show()
# Out:
# +-----------------+
# |              age|
# +-----------------+
# |   65 to 74 years|
# |   55 to 64 years|
# |75 years and over|
# |    0 to 24 years|
# |   25 to 34 years|
# |65 years and over|
# |   All age groups|
# |   45 to 54 years|
# |   35 to 44 years|
# +-----------------+

# %% [markdown]
# ### Create "45 to 64" column for income

# %%
incDist = spark.read.format("jdbc").option("url", 
                               "jdbc:sqlite:/home/benmo/Data/Databases/income.db").option(
                                       "dbtable", "incomeDist").load() 

incDistx = incDist.select('*').where(incDist.AGE.isin({'45 to 54 years', '55 to 64 years'})).toPandas()  # Select ages to combine 

incDistx.Value = incDistx.Value.astype(str).apply(lambda x: re.sub('[^0-9]','', x)).apply(pd.to_numeric) # Value column -> convertable string


"""_______________________Retain old identifiers to merge later__________________________"""
newVecCoord = incDistx[incDistx.AGE == '45 to 54 years'].drop(columns=['AGE','Value'])                   
newVecCoord[['Vector','Coordinate']] = newVecCoord[['Vector','Coordinate']].apply(lambda x: 'new-' + x)


"""_______________________Create Agrregated Age Column___________________________________"""
incDistx.drop(columns=['Vector','Coordinate'],inplace=True)
temp = pd.pivot_table(incDistx, values='Value', index=incDistx.columns[incDistx.columns.isin(['AGE','Value'])==False].tolist(),
                      columns=['AGE'],aggfunc=np.mean)
temp['Value'] = temp.sum(axis=1)
temp.drop(columns=['45 to 54 years','55 to 64 years'], inplace=True)
temp['AGE'] = '45 to 64 years'
temp.reset_index(inplace=True)
temp.index.name = 'Index'



mergecols = ['Ref_Date', 'GEO','Geographical classification', 'SEX','INC'] # columns to merge old identifiers with new Age column


temp=temp.merge(newVecCoord,on=mergecols,how='left')                       # merge
temp.Value = temp.Value.astype(str)
temp
# Out:
#        Ref_Date      GEO Geographical classification         SEX  \
# 0          2000  Alberta                              Both sexes
# 1          2000  Alberta                              Both sexes
# 2          2000  Alberta                              Both sexes
# 3          2000  Alberta                              Both sexes
# 4          2000  Alberta                              Both sexes
# 5          2000  Alberta                              Both sexes
# 6          2000  Alberta                              Both sexes
# 7          2000  Alberta                              Both sexes
# 8          2000  Alberta                              Both sexes
# 9          2000  Alberta                              Both sexes
# 10         2000  Alberta                              Both sexes
# 11         2000  Alberta                              Both sexes
# 12         2000  Alberta                              Both sexes
# ...

# %%
"""_________________________Update Database________________________"""

conn = db.connect("/home/benmo/Data/Databases/income.db")


temp.to_sql('incomeDist', con=conn, if_exists='append', index=False)
# Out:
# /home/benmo/intelpython3/lib/python3.6/site-packages/pandas/core/generic.py:2127: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   dtype=dtype)

# %% [markdown]
# ### Clean Re-Formatted SDMX tables

# %% [markdown]
# #### 2001 Census

# %%
tempdf = spark.read.format("csv").option("header", "true").load(
    "/home/benmo/Apps/SDMX_Converter_Platform-Independent_v.3.1.7_2014.06.30/Converter_Data/Output Files/census2001.csv")


census2001 = tempdf.select(['01', '11','12','13','14','15','23901360']).where(tempdf['13'] == 1).toPandas()
census2001 = census2001.drop(columns='13').rename(columns={'01' : 'geo', '11' : 'sex', '12' : 'age', '14' : 'educ', '15' : 'labor', '23901360' : 'Value'})

# %% [markdown]
# #### 2006 Census

# %%
tempdf = spark.read.format("csv").option("header", "true").load(
    "/home/benmo/Apps/SDMX_Converter_Platform-Independent_v.3.1.7_2014.06.30/Converter_Data/Output Files/census2006.csv")


census2006 = tempdf.select(['01', '11','12','13','14','15','16','25664220']).where((tempdf['11'] == 1) & (tempdf['15'] == 1)).toPandas()
census2006 = census2006.drop(columns=['11', '15']).rename(columns={'01' : 'geo', '12' : 'educ', '13' : 'age', '14' : 'sex', '16' : 'labor', '25664220' : 'Value'})

# %% [markdown]
# #### 2011 Census

# %%
tempdf = spark.read.format("csv").option("header", "true").load(
    "/home/benmo/Apps/SDMX_Converter_Platform-Independent_v.3.1.7_2014.06.30/Converter_Data/Output Files/census2011.csv")


census2011 = tempdf.select(['01', '11','12','13','14','15','16','27259525']).where((tempdf['11'] == 1) & (tempdf['12'] == 1)).toPandas()
census2011 = census2011.drop(columns=['11', '12']).rename(columns={'01' : 'geo', '13' : 'age', '14' : 'sex', '15' : 'educ', '16' : 'labor', '27259525' : 'Value'})

# %% [markdown]
# #### 2016 Census

# %%
tempdf = spark.read.format("csv").option("header", "true").load(
    "/home/benmo/Apps/SDMX_Converter_Platform-Independent_v.3.1.7_2014.06.30/Converter_Data/Output Files/census2016.csv")


census2016 = tempdf.select(['01', '11','12','13','14','15','16','17','28643015']).where(((tempdf['11'] == 1) & (tempdf['13'] == 1)) & (tempdf['16'] == 1)).toPandas()
census2016 = census2016.drop(columns=['11','13', '16']).rename(columns={'01' : 'geo', '12' : 'educ', '14' : 'age', '15' : 'sex', '17' : 'labor', '28643015' : 'Value'})

# %%
"""_________________COMBINE CENSUS DATA & RECODE VALUES_________________"""

def recode(df, dataKeys):
    df.geo = df.geo.apply(lambda x: dataKeys['geo'][dataKeys['geo'].geoid == x]['geo'].tolist()[0])
    df.educ = df.educ.apply(lambda x: dataKeys['educ'][dataKeys['educ'].educid == x]['educ'].tolist()[0])
    df.labor = df.labor.apply(lambda x: dataKeys['labor'][dataKeys['labor'].laborid == x]['labor'].tolist()[0])
    df.age = df.age.apply(lambda x: dataKeys['age'][dataKeys['age'].ageid == x]['age'].tolist()[0])
    df.sex = df.sex.apply(lambda x: dataKeys['sex'][dataKeys['sex'].sexid == x]['sex'].tolist()[0])
    return df



census2001 = recode(census2001, dataKeysDict[2001])
census2006 = recode(census2006, dataKeysDict[2006])
census2011 = recode(census2011, dataKeysDict[2011])
census2016 = recode(census2016, dataKeysDict[2016])

census2001['year'] = 2001
census2006['year'] = 2006
census2011['year'] = 2011
census2016['year'] = 2016

conn = db.connect("/home/benmo/Data/Databases/health.db")
census2001.to_sql('educ_cities', con=conn, if_exists='append', index=False)   #send data to database
census2006.to_sql('educ_cities', con=conn, if_exists='append', index=False)   #send data to database
census2011.to_sql('educ_cities', con=conn, if_exists='append', index=False)   #send data to database
census2016.to_sql('educ_cities', con=conn, if_exists='append', index=False)   #send data to database

# %% [markdown]
# # Define Variables

# %%
uri="postgresql://postgres:justbusted@localhost:5433/geodata"
engine = sqlalchemy.create_engine(uri)


stata = 0    # dont write to stata files in section 4.1
shape = 1    # write the shapefiles in section 4.1

healthShp = gpd.read_file("/home/benmo/Data/GeoData/canHealth.shp")               # get shapefile for health regions
canadaShp = gpd.read_postgis("select * from can_adm3", uri, 
                        geom_col='geom', crs={'init': 'epsg:4326'})               # get shapefile for Canada (incl. city names)


    
healthVars, incDistVars = {}, {}

healthVars['hrprof'] = ['Current smoker, daily or occasional', 
'Arthritis', 'Current smoker, daily',  
'5 or more drinks on one occasion, at least once a month in the past year', 'Heavy drinking', 
'Fruit and vegetable consumption, 5 times or more per day', 
'Physical activity during leisure-time, moderately active or active', 
'Physical activity during leisure-time, inactive', 
'Body mass index, self-reported, adult (18 years and over), overweight or obese',  
'Body mass index, self-reported, adult (18 years and over), obese', 
'Sense of belonging to local community, somewhat strong or very strong', 
'Has a regular medical doctor', 
'Contact with a medical doctor in the past 12 months',  
'Mood disorder', 'Wears a helmet when riding a bicycle, always', 
'Functional health, good to full', 
'Injuries in the past 12 months causing limitation of normal activities', 'Injuries in the past 12 months, sought medical attention', 
'Chronic obstructive pulmonary disease (COPD)', 
'Perceived health, very good or excellent', 
'Perceived health, fair or poor', 
'Perceived mental health, very good or excellent', 
'Perceived mental health, fair or poor', 
'Life satisfaction, satisfied or very satisfied', 
'Perceived life stress, quite a lot (15 years and over)', 
'Diabetes', 'Asthma', 'High blood pressure', 
'Pain or discomfort by severity, moderate or severe', 
'Pain or discomfort that prevents activities', 
'Participation and activity limitation, sometimes or often']


healthVars['unit'] = ['Number of persons', 'Percent']

healthVars['age'] = ['20 to 34 years', '35 to 44 years',
        '45 to 64 years', 'Total, 12 years and over']

incDistVars['age'] = ['25 to 34 years', '35 to 44 years', 
        '45 to 64 years', 'All age groups']

# %% [markdown]
# ## Join City & Health Shapefiles

# %%
canadaShp['geo_idx'] = canadaShp.index.tolist()         #create column containing unique city index


cities_inH = gpd.sjoin(canadaShp, healthShp, 
                       how='left', op= 'within')        #spatially join city & health region shapefiles

#note: this operation only joins cities w/ boundaries completely within health regions

cities_inH = cities_inH[cities_inH['HR_UID'].isna() == False] #drop cities not within h-regions


missingcities = gpd.sjoin(canadaShp, healthShp, 
                          how='left', op= 'within')           #collect cities missed by spatial join

missingcities = missingcities[missingcities['HR_UID'].isna() == True][
        missingcities['engtype_3'] == 'City']                 #select only cities (pop > ~10,000)

missingcities.geom = missingcities.geom.apply(lambda x: x.centroid) #get centroid of cities

missingcities = gpd.sjoin(missingcities[list(filter(lambda x: 
                                                    x not in ['index_left','index_right'],
                                                    missingcities.columns.tolist()))],
                                        healthShp, how='left', op='within') #add the missing cities 

#note: missing cities added to shapefile by joining city centroid to the appropriate h-region

cities = cities_inH.append(missingcities)       #collect all the cities (missing/non-missing) to one shapefile


"""_____________Merge the Health Shapefile with the edited Canada-City shapefile___________"""

healthCanShp = gpd.sjoin(healthShp, cities[['geom', 'geo_idx', 'name_1', 
                                               'name_3', 'engtype_3'] ], how='left', op='contains')
# Out:
# /home/benmo/intelpython3/lib/python3.6/site-packages/geopandas/geodataframe.py:398: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# /home/benmo/intelpython3/lib/python3.6/site-packages/pandas/core/frame.py:6201: FutureWarning:
#
# Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False

# %%
healthCanShp.name_3[healthCanShp.geo_idx == 3367] = 'Montréal' # Montreal suburb (location same as Montreal)
healthCanShp.geo_idx[healthCanShp.geo_idx == 3367] = 3368      # Actual Montreal id

  
provinces = canadaShp['name_1'].unique().tolist()
hRegions = healthShp.HR_UID.unique().tolist()
# Out:
# /home/benmo/intelpython3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/benmo/intelpython3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# # Run Calculations

# %% [markdown]
# ## Prepare Data for Analysis

# %%
  
for i, (varH, varI) in enumerate(zip(healthVars['age'], incDistVars['age'])):

    for j, hType in enumerate(healthVars['hrprof']):  #start ay number 5!!!!!!!

        """_____________HEALTH DATA_______________"""

        healthx = get_Healthx(hRegions,spark, i, j) # get CCHS data for specific health variable (j) & age (i)

        healthData = healthShp.merge(healthx.drop(columns=['Vector','Coordinate']), how ='left', left_on='HR_UID', 
                                                             right_on='Geographicalclassification') #merge w/ geographical data
        healthData.rename(columns={'Ref_Date' : 'ref_date', 'GEO' : 'geo', 'AGE' : 'age', 'SEX' : 'sex',
                                  'HRPROF' : 'hrprof', 'Geographicalclassification' : 'geographicalclassification',
                                  'Value' : 'value'}, inplace=True)
        healthData.value = pd.to_numeric(healthData.value,errors='coerce')
    
        
        #===================> only need to calculate income distributions for each age range (ie. j = 0) ===========>
        if j==0:

            """_____________INCOME DATA_______________"""

            incDistx = get_incDistx(provinces,spark, i,j) # get age/sex specific income distribution data
            cities = incDistx.GEO.unique()                # get list of cities incl. in income data
            
            cities = pd.DataFrame(data=np.array([cities, list(map(lambda x: closestIndex(canadaShp['name_3'], x), cities))]).T,
                        columns=['geo','geo_id'])         # get geo_id of cities in income data

            
            incDistx.rename(columns={'GEO' : 'geo'}, inplace=True)
            incDistx = incDistx.merge(cities, how='left', on='geo') # data now includes geo_id for merging



            """_____________FORMAT DATA_______________"""

            temp = incDistx.rename(columns={'Ref_Date' : 'ref_date', 'GEO' : 'geo', 'SEX' : 'sex', 'AGE' : 'age', 'INC' : 'inc', 'Value' : 'value'})
            
            
            #================> the following code re-shapes the data and creates a column for each income bin =====>
            incTable = pd.pivot_table(temp[['ref_date', 'geo','geo_id', 'sex','inc','value']], 
                                values='value', index=['ref_date', 'geo','geo_id', 'sex'],columns=['inc'],aggfunc=np.mean)
            
            try:
                incTable.drop(columns=['5-year percent change of median income',
                                       'Median total income (dollars)'],inplace=True) # delete unused cols if they exist
            except:
                pass
            
            renamecol = lambda x: re.sub('[^0-9]','', x) # define func. to rename income bins to the upper bin range value
            
            incTable = incTable.rename(columns=dict(zip(incTable.columns[:-1].tolist(), 
                                                        list(map(renamecol, incTable.columns[:-1].tolist()))))) # rename cols

            #===============> The following code converts data from total persons making over $x to a % of population====>
            incTable['200000'] = incTable.apply(lambda x: x['100000']/x[incTable.columns[-1]]*100, axis=1)
            incTable['100000'] = incTable.apply(lambda x: (x['75000'] - x['100000'])/x[incTable.columns[-1]]*100, axis=1) 
            incTable['75000'] = incTable.apply(lambda x: (x['50000'] - x['75000'])/x[incTable.columns[-1]]*100, axis=1)
            incTable['50000'] = incTable.apply(lambda x: (x['35000'] - x['50000'])/x[incTable.columns[-1]]*100, axis=1)  
            incTable['35000'] = incTable.apply(lambda x: (x['20000'] - x['35000'])/x[incTable.columns[-1]]*100, axis=1) 
            incTable['20000'] = incTable.apply(lambda x: (x['10000'] - x['20000'])/x[incTable.columns[-1]]*100, axis=1) 
            incTable['10000'] = incTable.apply(lambda x: (x[incTable.columns[-1]] - x['10000'])/x[incTable.columns[-1]]*100, axis=1)



            incTable.rename(columns={'200000' : 'Over 100000'}, inplace=True)                # rename cols
            incTable.drop(columns=['5000','15000','25000','150000', '250000'],inplace=True)  # drop unused cols

            
            for col in incTable.columns.tolist():
                incTable[col][incTable[col].isna() == True] = 0     # na values have 0% of population within bin
                
            incTable['totalpercent'] = incTable.apply(
                    lambda x: sum([float(x[xi]) for xi in incTable.columns[:-1].tolist()]), axis=1) # used to check if %'s add up to 1

            #=============> send data to R and return smoothed income distribution ==========> 
            incTable['dist'] = incTable.apply(lambda x: get_incDist([x['10000'],
                                                                     x['20000'], x['35000'],
                                                                     x['50000'], x['75000'],
                                                                     x['100000'], x['Over 100000']]), axis=1)

            #===========> creates data for more refined income bins generated by the smoothed distribution ===>
            #===============> calls R to calculate inequality metrics given the income distributions =========>
            incTable['tempdist'] = incTable.dist.apply(lambda x: x.rvs(size=30000))
            incTable['gini'] = incTable.tempdist.apply(get_gini)
            incTable['median'] = incTable.dist.apply(lambda x: x.median())
            incTable['atkLow'] = incTable.tempdist.apply(lambda x: get_atkinson(x, eps=0.5))
            incTable['atkHigh'] = incTable.tempdist.apply(lambda x: get_atkinson(x, eps=2))
            incTable['palma'] = incTable.apply(lambda x: get_palma(x['dist'], x['tempdist']), axis=1)
            incTable = incTable.drop(columns='tempdist')

            #============> the only variables which are needed later are retained in the 'temp' dataframe ======>
            temp = incTable[['Total persons with income','gini', 'atkLow',
                             'atkHigh', 'palma', 'median']].apply(
                             pd.to_numeric).set_index(
                                     incTable.index.get_level_values(2).astype(int))
            
            
            
            #===========> reshape dataframe (ie. move sex,year from index to columns) ===>
            temp.index.set_names('x', inplace=True)
            temp['Year'] = incTable.index.get_level_values(0).astype(int).tolist()
            temp['geo_id'] = incTable.index.get_level_values(2).tolist()
            temp['Sex'] = incTable.index.get_level_values(3).astype(str).tolist()

            tempInc = pd.pivot_table(temp[['Year','geo_id', 'Sex', 
                                               'Total persons with income', 'gini',
                                               'atkLow','atkHigh','palma','median']], 
                                                values=['Total persons with income', 'gini',
                                                        'atkLow','atkHigh', 'median'], index='geo_id',
                                                        columns=['Year', 'Sex'],aggfunc=np.mean)

            # note: this makes it so that the only index is geography, such that all the data can easily be joined
            # on the geo_id and saved as a shapefile for geographical visualization/processing.

        
        #====================> Reshape health data for merging with income data =============>
        healthData.rename(columns={'ref_date' : 'Year', 'age' : 'Age', 'sex' : 'Sex', 'UNIT' : 'unit'}, inplace = True)

        healthData[['Age','Sex', 'hrprof', 'unit']] = healthData[['Age',
               'Sex', 'hrprof', 'unit']].astype(str)

        healthData[['Year','value']] = healthData[['Year','value']].apply(pd.to_numeric)

        tempHealth = pd.pivot_table(healthData[['HR_UID',
                                    'Year', 'Sex', 'value']], 
                                            values=['value'], index=['HR_UID'],
                                                    columns=['Year', 'Sex'],aggfunc=np.mean)


        """_______SHAPEFILES!!!!!!!!!!_________"""
        ineqShapeCities = healthCanShp.merge(tempInc, how='inner', left_on='geo_idx', right_index=True)
        healthShapeRegions = healthCanShp.merge(tempHealth, left_on='HR_UID', 
                                              right_index=True).merge(
                                                      tempInc, left_on='geo_idx', right_index=True)




        """________CREATE DATA TABLE____________"""

        regionsData = healthCanShp.merge(temp, how='inner', left_on='geo_idx', right_index=True)
        regionsData.rename(columns={'hr_uid' : 'HR_UID', 'eng_label' : 'ENG_LABEL'}, inplace=True)
        regionsData[['HR_UID', 'ENG_LABEL', 'name_3', 'geo_idx']] = regionsData[['HR_UID', 'ENG_LABEL', 'name_3', 'geo_idx']].astype(str)
        healthData.rename(columns={'ref_date' : 'Year', 'age' : 'Age', 'sex' : 'Sex'}, inplace = True)

        healthData[['Age','Sex', 'hrprof', 'unit']] = healthData[['Age',
               'Sex', 'hrprof', 'unit']].astype(str)
        healthData[['Year','value']] = healthData[['Year','value']].apply(pd.to_numeric)

        regionsData = regionsData.merge(healthData[['HR_UID','Year', 'Age',
               'Sex', 'hrprof', 'unit', 'value']], how='left', on=['HR_UID','Year','Sex'])



        diri = "/home/benmo/Data/GeoData/Inequality/{age}".format(age=varI)
        dirj = "/{htype}".format(htype=hType)

        if not os.path.exists(diri + dirj):
            os.mkdir(diri + dirj)

        """______________________SEND TO STATA _____________________________"""
        if stata == 1:
            regionsData[varI] = varI
            regionsData[hType] = hType
            regionsData[['HR_UID', 'ENG_LABEL', 'name_1', 'name_3', 'geo_idx', 'gini','atkLow','atkHigh','palma','median','Year','Sex', 'Age', 'hrprof',
                         'Total persons with income', 'unit', 'value'] + [
                                 varI, hType]].astype(str).to_stata(diri + dirj + "/stataHealth.dta")


        """______________________SEND TO PICKLE _____________________________"""

        regionsData[varI] = varI
        regionsData[hType] = hType
        regionsData[['HR_UID', 'ENG_LABEL', 'name_1', 'name_3', 'geo_idx', 'gini','atkLow','atkHigh','palma','median','Year','Sex', 'Age', 'hrprof',
                     'Total persons with income', 'unit', 'value'] + [
                             varI, hType]].to_pickle(diri + dirj + "/pyHealth.pkl")
        if j == 0:
            incTable.to_pickle(diri + dirj + "/pyIncomeTable.pkl")

        ineqShapeCities.to_pickle(diri + dirj + "/pyShpCities.pkl") 
        healthShapeRegions.to_pickle(diri + dirj + "/pyShpRegions.pkl")


        """______________________SAVE SHAPEFILES TO DISK_____________________________"""

        if shape == 1:
            ineqShapeCities.rename(columns=lambda x: tuple2str(x), inplace=True)
            healthShapeRegions.rename(columns=lambda x: tuple2str(x), inplace=True)

            ineqShapeCities.to_file(diri + dirj + "/ineqCity.shp", driver='ESRI Shapefile')
            healthShapeRegions.to_file(diri + dirj + "/ineqRegion.shp", driver='ESRI Shapefile')

spark.stop()

# %% [markdown]
# ## Merge Other Datasets (Food Insec./Unemp./Education)

# %% [markdown]
# ### Merge with Food Insecurity

# %%
columns = ['HR_UID', 'ENG_LABEL', 'name_1', 'name_3', 'geo_idx', 'gini','atkLow','atkHigh','palma', 'median',
       'Year', 'Sex', 'Age', 'hrprof', 'Total persons with income', 'unit',
       'value']


data = pd.DataFrame([])

for age in incDistVars['age']:
    dfListj = [pd.read_pickle(
        "/home/benmo/Data/GeoData/Inequality/{i}/{j}/pyHealth.pkl".format(i=age, 
                                                          j=cati)) for cati in healthVars['hrprof']]    
    temp = pd.DataFrame(reduce(lambda x, y: x[columns].append(y[columns], ignore_index=True),dfListj))
    data = data.append(temp, ignore_index=True)


    
data[['ENG_LABEL', 'name_1', 'name_3',
       'Sex', 'Age', 'hrprof', 'unit']] = data[
    ['ENG_LABEL', 'name_1', 'name_3',
       'Sex', 'Age', 'hrprof', 'unit']].astype(str)


data[['HR_UID','geo_idx', 'gini','atkLow','atkHigh','palma', 'median',
       'Year', 'Total persons with income',
       'value']] = data[['HR_UID','geo_idx', 'gini','atkLow','atkHigh','palma', 'median',
       'Year', 'Total persons with income',
       'value']].apply(pd.to_numeric, errors = 'coerce')


data = pd.pivot_table(data[['HR_UID', 'name_1', 'geo_idx', 'Year', 'Sex', 'Age','hrprof', 'value', 
                            'gini','atkLow','atkHigh','palma', 'median', 'Total persons with income','ENG_LABEL','name_3']], 
                     values = ['value'], index = ['HR_UID', 'name_1', 'geo_idx', 'Year', 'Sex', 'Age',
                                                 'gini','atkLow','atkHigh', 'palma','median', 'Total persons with income','ENG_LABEL','name_3'],
                     columns = ['hrprof'])


    
data = data.reset_index()    

colnames_l0 = ['HR_UID', 'name_1', 'geo_idx', 'Year', 'Sex', 'Age',
              'gini','atkLow','atkHigh','palma', 'median', 'Total persons with income','ENG_LABEL','name_3']
colnames_l1 = [colname for colname in list(filter(lambda x: x !=  '', data.columns.get_level_values(1)))]

data = pd.DataFrame(data=data.values, columns= colnames_l0 + colnames_l1)
data
# Out:
#       HR_UID                     name_1 geo_idx  Year         Sex  \
# 0       1011  Newfoundland and Labrador    1936  2008  Both sexes
# 1       1011  Newfoundland and Labrador    1936  2008  Both sexes
# 2       1011  Newfoundland and Labrador    1936  2008  Both sexes
# 3       1011  Newfoundland and Labrador    1936  2008  Both sexes
# 4       1011  Newfoundland and Labrador    1936  2008  Both sexes
# 5       1011  Newfoundland and Labrador    1936  2008  Both sexes
# 6       1011  Newfoundland and Labrador    1936  2008  Both sexes
# 7       1011  Newfoundland and Labrador    1936  2008  Both sexes
# 8       1011  Newfoundland and Labrador    1936  2008     Females
# 9       1011  Newfoundland and Labrador    1936  2008     Females
# 10      1011  Newfoundland and Labrador    1936  2008     Females
# 11      1011  Newfoundland and Labrador    1936  2008     Females
# 12      1011  Newfoundland and Labrador    1936  2008     Females
# ...

# %%
food = spark.read.format("jdbc").option("url", 
                               "jdbc:sqlite:/home/benmo/Data/Databases/health.db").option(
                                       "dbtable", "FoodInsec").load()

food_df2012 = food.select('*').where((food.STATUS == 'Food insecure, moderate and severe') & 
                    (food.Ref_Date == '2011/2012') & (
                    food.UNIT == 'Percent of persons in households')).toPandas()


food_df2008 = food.select('*').where((food.STATUS == 'Food insecure, moderate and severe') & 
                    (food.Ref_Date == '2007/2008') & (
                    food.UNIT == 'Percent of persons in households')).toPandas()


food_df2012.Geographicalclassification = food_df2012.Geographicalclassification.apply(
            lambda x: x[:4])
food_df2008.Geographicalclassification = food_df2008.Geographicalclassification.apply(
            lambda x: x[:4])

food_df2012.rename(columns={'Ref_Date' : 'Year','Geographicalclassification' : 'HR_UID','AGE' : 'Age',
 'SEX' : 'Sex', 'Value' : 'Pct Food Insecure'}, inplace=True)
food_df2008.rename(columns={'Ref_Date' : 'Year','Geographicalclassification' : 'HR_UID','AGE' : 'Age',
 'SEX' : 'Sex', 'Value' : 'Pct Food Insecure'}, inplace=True)    
    
food_df2012.GEO[food_df2012.GEO == 'Quebec'] = 'Québec'
food_df2008.GEO[food_df2008.GEO == 'Quebec'] = 'Québec'


food_df2012['Prov Food Insecurity2012'] = food_df2012['Pct Food Insecure']
food_df2008['Prov Food Insecurity2008'] = food_df2008['Pct Food Insecure']

food_df2012['Pct Food Insecure2012'] = food_df2012['Pct Food Insecure']
food_df2008['Pct Food Insecure2008'] = food_df2008['Pct Food Insecure']

data = data.merge(food_df2012[['GEO', 'Age', 'Sex', 'Prov Food Insecurity2012']], 
           how='left', left_on=['name_1', 'Age', 'Sex'],
           right_on=['GEO', 'Age', 'Sex']).merge(food_df2008[
                        ['GEO', 'Age', 'Sex', 'Prov Food Insecurity2008']], 
           how='left', left_on=['name_1', 'Age', 'Sex'],
           right_on=['GEO', 'Age', 'Sex'])

data = data.merge(food_df2012[['HR_UID', 'Age', 'Sex', 'Pct Food Insecure2012']], 
           how='left', on=['HR_UID', 'Age', 'Sex']).merge(
    food_df2008[['HR_UID', 'Age', 'Sex', 'Pct Food Insecure2008']], 
           how='left', on=['HR_UID', 'Age', 'Sex'])


strcols = ['name_1','Sex','Age','GEO_x','GEO_y','ENG_LABEL','name_3']

data[strcols] = data[strcols].astype(str)
data[list(filter(lambda x: x not in strcols, data.columns))] = data[
    list(filter(lambda x: x not in strcols, data.columns))].apply(lambda x: pd.to_numeric(x, errors='coerce'))


data = data[data.Age.isna() == False]


#data.to_stata("/home/benmo/Data/GeoData/Inequality/healthStata.dta")

# %% [markdown]
# ### Merge with Unemployment

# %%
unemp = spark.read.format("jdbc").option("url", 
                               "jdbc:sqlite:/home/benmo/Data/Databases/health.db").option(
                                       "dbtable", "unemp").load()

unemp_df = unemp.select('*').where(unemp.LABFORCE == 'Unemployment rate, 15 years and over').toPandas()

unemp_df.Geographicalclassification = unemp_df.Geographicalclassification.apply(lambda x: x[:4])


unemp_df.rename(columns={'Ref_Date' : 'Year','Geographicalclassification' : 'HR_UID', 'Value' : 'Unemployment'}, inplace=True)

unemp_df = unemp_df.apply(lambda x: pd.to_numeric(x, errors ='coerce'))

unemp_df = unemp_df[unemp_df.HR_UID.isna() == False]

data = data.merge(unemp_df[['Year','HR_UID', 'Unemployment']], 
           how='left', on=['Year','HR_UID'])

# %% [markdown]
# ### Merge with Education

# %%
educ = spark.read.format("jdbc").option("url", 
                               "jdbc:sqlite:/home/benmo/Data/Databases/health.db").option(
                                       "dbtable", "educ_cities").load()



educ_levels = ["Total - Highest level of schooling", 
               "Total - Highest certificate, diploma or degree",
               
               'No certificate, diploma or degree',
               
               "With high school graduation certificate",
               "High school certificate or equivalent",
               "High school diploma or equivalent",
               "Secondary (high) school diploma or equivalency certificate",
               
               "College, CEGEP or other non-university certificate or diploma",
               "University certificate or diploma below the bachelor level",
               "University certificate or diploma below bachelor level",
               "College",
               
               "Trades certificate or diploma",
               "Apprenticeship or trades certificate or diploma",
               
                "With bachelor's degree or higher",
                "University certificate, diploma or degree at bachelor level or above"]





educ_df = educ.select("*").where(

        ((educ.labor.isin(["Total - Labour force activity", "Total - Labour force status"])) &

        (educ.age.isin(["Total - Age groups", "Total - Age",'25 to 34 years','35 to 44 years',
                       '35-39 years', '40-44 years', '25-29 years', '30-34 years', 
                        '30-34 years', '45-64 years', '45 to 54 years','55 to 64 years']))) & 
        (educ.educ.isin(educ_levels))).toPandas()

# %%
provinces2 = ['British Columbia / Colombie-Britannique', 'Yukon Territory - Territoire du Yukon', 
'Northwest Territories / Territoires du Nord-Ouest','Prince Edward Island - Ã\x8ele-du-Prince-Ã\x89douard', 
'Newfoundland and Labrador - Terre-Neuve-et-Labrador', 'British Columbia - Colombie-Britannique',
'Yukon Territory / Territoire du Yukon', 'Ontario', 'Alberta', 'Manitoba', 'Nunavut', 'Saskatchewan',
'Northwest Territories / Territoires du Nord-Ouest', 'Quebec / QuÃ©bec', 'Quebec - QuÃ©bec', 'New Brunswick / Nouveau-Brunswick', 
'Prince Edward Island / Ã\x8ele-du-Prince-Ã\x89douard', 'Newfoundland and Labrador / Terre-Neuve-et-Labrador',
'Nova Scotia - Nouvelle-Ã\x89cosse', 'New Brunswick - Nouveau-Brunswick', 'Nova Scotia / Nouvelle-Ã\x89cosse']

provinces2+=['Canada']



educ_df.geo[educ_df.geo == 'Quebec - QuÃ©bec'] = 'Québec'
educ_df.geo[educ_df.geo.apply(lambda x: x in ['British Columbia / Colombie-Britannique',
                           'British Columbia - Colombie-Britannique']) == True] = 'British Columbia'
educ_df.geo[educ_df.geo.apply(lambda x: x in ['Northwest Territories / Territoires du Nord-Ouest',
                           'Northwest Territories / Territoires du Nord-Ouest']) == True] = 'Northwest Territories'
educ_df.geo[educ_df.geo.apply(lambda x: x in ['Newfoundland and Labrador - Terre-Neuve-et-Labrador',
                           'Newfoundland and Labrador / Terre-Neuve-et-Labrador']) == True] = 'Newfoundland and Labrador'
educ_df.geo[educ_df.geo.apply(lambda x: x in ['New Brunswick - Nouveau-Brunswick',
                           'New Brunswick / Nouveau-Brunswick']) == True] = 'New Brunswick'
educ_df.geo[educ_df.geo.apply(lambda x: x in ['Nova Scotia - Nouvelle-Ã\x89cosse',
                           'Nova Scotia / Nouvelle-Ã\x89cosse']) == True] = 'Nova Scotia'
educ_df.geo[educ_df.geo.apply(lambda x: x in ['Prince Edward Island / Ã\x8ele-du-Prince-Ã\x89douard',
                           'Prince Edward Island - Ã\x8ele-du-Prince-Ã\x89douard']) == True] = 'Prince Edward Island'
educ_df.geo[educ_df.geo.apply(lambda x: x in ['Yukon Territory - Territoire du Yukon',
                           'Yukon Territory / Territoire du Yukon']) == True] = 'Yukon'




educ_df.Value = pd.to_numeric(educ_df.Value, errors='coerce')

educ_df = pd.pivot_table(educ_df[['year','geo','sex', 'age', 'educ','Value']], 
                     values = 'Value', index = ['year','geo','sex', 'educ'],
                     columns = 'age')



educ_df['25 to 34 years'][educ_df.index.get_level_values(0) == 2001] = educ_df['25-29 years'] + educ_df['30-34 years']
educ_df['35 to 44 years'][educ_df.index.get_level_values(0) == 2001] = educ_df['35-39 years'] + educ_df['40-44 years']

educ_df.rename(columns={'45-64 years' : '45 to 64 years'}, inplace=True)

educ_df['45 to 64 years'][((educ_df.index.get_level_values(0) == 2006) |
                          (educ_df.index.get_level_values(0) == 2011)) | 
                          (educ_df.index.get_level_values(0) == 2016)] = educ_df['45 to 54 years'] + educ_df['55 to 64 years']


educ_df["Total - Age groups"][educ_df.index.get_level_values(0) == 2016] = educ_df['Total - Age']



educ_df = educ_df.unstack()[['25 to 34 years', '35 to 44 years',
                        '45 to 64 years', 'Total - Age groups']]


cols = educ_df.columns.get_level_values(0).unique()


for col in cols:
    educ_df[idx[col,'Population']] = educ_df.loc[:,idx[col,'Total - Highest level of schooling']].apply(np.nan_to_num) + educ_df.loc[:,idx[
        col, 'Total - Highest certificate, diploma or degree']].apply(np.nan_to_num)

    educ_df[idx[col,'lessThanHS']] = educ_df.loc[:,idx[col,'No certificate, diploma or degree']].apply(
        np.nan_to_num) / educ_df.loc[:,idx[col,'Population']].apply(np.nan_to_num) 

    
    educ_df[idx[col,'High School']] = (educ_df.loc[:,idx[col,'High school certificate or equivalent']].apply(np.nan_to_num) + educ_df.loc[:,idx[
        col,'High school diploma or equivalent']].apply(np.nan_to_num) + educ_df.loc[:,idx[
        col,'Secondary (high) school diploma or equivalency certificate']].apply(np.nan_to_num) + educ_df.loc[:,idx[
        col,'With high school graduation certificate']].apply(np.nan_to_num)) / educ_df.loc[:,idx[col,'Population']].apply(np.nan_to_num)
 
    educ_df[idx[col,'CollegeDiploma']] = (educ_df.loc[:,idx[col,"College, CEGEP or other non-university certificate or diploma"]].apply(np.nan_to_num) + educ_df.loc[:,idx[
        col,"University certificate or diploma below the bachelor level"]].apply(np.nan_to_num) + educ_df.loc[:,idx[
        col,"University certificate or diploma below bachelor level"]].apply(np.nan_to_num) + educ_df.loc[:,idx[
        col,"College"]].apply(np.nan_to_num)) / educ_df.loc[:,idx[col,'Population']].apply(np.nan_to_num)

    educ_df[idx[col,'Trades']] = (educ_df.loc[:,idx[col,'Apprenticeship or trades certificate or diploma']].apply(np.nan_to_num) + educ_df.loc[:,idx[
        col,'Trades certificate or diploma']].apply(np.nan_to_num)) / educ_df.loc[:,idx[col,'Population']].apply(np.nan_to_num) 

                              
    educ_df[idx[col,'University']] = (educ_df.loc[:,idx[col,'University certificate, diploma or degree at bachelor level or above']].apply(np.nan_to_num) + educ_df.loc[:,idx[
        col,"With bachelor's degree or higher"]].apply(np.nan_to_num)) / educ_df.loc[:,idx[col,'Population']].apply(np.nan_to_num)



dropcols = ['Apprenticeship or trades certificate or diploma', 'High school certificate or equivalent', 
            'High school diploma or equivalent', 'Secondary (high) school diploma or equivalency certificate', 
            'Total - Highest certificate, diploma or degree', 'Total - Highest level of schooling', 
            'Trades certificate or diploma', 'University certificate, diploma or degree at bachelor level or above', 
            "With bachelor's degree or higher", "With high school graduation certificate", "College",
           "College, CEGEP or other non-university certificate or diploma", "University certificate or diploma below the bachelor level",
           "University certificate or diploma below bachelor level", 'No certificate, diploma or degree']

educ_df = educ_df.stack('age').drop(columns=dropcols).reset_index()

educ_df.rename(columns={'year' : 'Year','sex' : 'Sex', 'age' : 'Age'}, inplace=True)

educ_df.Sex[educ_df.Sex == 'Female'] = 'Females'
educ_df.Sex[educ_df.Sex == 'Male'] = 'Males'
educ_df.Sex[educ_df.Sex == 'Total - Sex'] = 'Both sexes'
# Out:
# /home/benmo/intelpython3/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/benmo/intelpython3/lib/python3.6/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/benmo/intelpython3/lib/python3.6/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# ...

# %%
educ_df.Age[educ_df.Age == '25 to 34 years'] = '20 to 34 years'
educ_df.Age[educ_df.Age == 'Total - Age groups'] = 'Total, 12 years and over'


cities = educ_df.geo[educ_df.geo.apply(lambda x: x in provinces2) == False].apply(
    lambda x: x[:12] if (((x.find(',') >=12) | 
                         (x.find('/') >=12)) |
                        x.find('-') >=12) else x[:x.find(',')]).unique()     # get list of cities & truncate
            
cities = pd.DataFrame(data=np.array([cities, list(map(lambda x: closestIndex(canadaShp['name_3'], x), cities))]).T,
            columns=['geo','geo_idx'])         # get geo_id of cities in education data

educ_df['geo_old'] = educ_df.geo

educ_df.geo = educ_df.geo.apply(
    lambda x: x[:12] if ((((x.find(',') >=12) | 
                         (x.find('/') >=12)) |
                        x.find('-') >=12)) else x[:x.find(',')])

educ_df = educ_df.merge(cities, how='left', on='geo') # data now includes geo_id for merging

educ_df.geo_idx = educ_df.geo_idx.apply(pd.to_numeric)

educ_df = educ_df.merge(healthCanShp[['geo_idx','HR_UID','name_1', 'name_3']], how='left', on='geo_idx')


educ_df[['Year','geo_idx','Population', 'lessThanHS', 
        'High School', 'CollegeDiploma', 'Trades','University','HR_UID']] = educ_df[['Year','geo_idx','Population',
                                                                                     'lessThanHS', 'High School', 
                                                        'CollegeDiploma', 'Trades','University','HR_UID']].apply(pd.to_numeric)

educ_df[['Age','Sex','geo','geo_old','HR_UID','name_1', 'name_3']] = educ_df[['Age','Sex','geo','geo_old',
                                                                   'HR_UID','name_1', 'name_3']].astype(str)

educ_df = educ_df[educ_df['lessThanHS'] != np. inf]
educ_df = educ_df[educ_df['CollegeDiploma'] != np. inf]
educ_df = educ_df[educ_df['High School'] != np. inf]
educ_df = educ_df[educ_df['Trades'] != np. inf]
educ_df = educ_df[educ_df['University'] != np. inf]
# Out:
# /home/benmo/intelpython3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/benmo/intelpython3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# $\alpha$

# %%
#data.to_stata("/home/benmo/Data/GeoData/Inequality/healthStataFull.dta")
educ_df.to_stata("/home/benmo/Data/GeoData/Inequality/StataEducCities.dta")
# Out:
# /home/benmo/intelpython3/lib/python3.6/site-packages/pandas/io/stata.py:2121: InvalidColumnName:
#
#
# Not all pandas column names were valid Stata variable names.
# The following replacements have been made:
#
#     b'High School'   ->   High_School
#
# If this is not what you expect, please make sure you have Stata-compliant
# column names in your DataFrame (strings only, max 32 characters, only
# alphanumerics and underscores, no Stata reserved words)

# %%
educ_df.columns
# Out:
# Index(['Year', 'geo', 'Sex', 'Age', 'High School', 'Population', 'Trades',
#        'University'],
#       dtype='object', name='educ')

# %%
# Out:
# ['No certificate, diploma or degree',
#  'High school certificate or equivalent',
#  'Postsecondary certificate, diploma or degree',
#  'Total - Highest level of schooling',
#  'University certificate or diploma below the bachelor level',
#  'Less than grade 9',
#  'University certificate or diploma below bachelor level',
#  "Bachelor's degree",
#  'Secondary (high) school diploma or equivalency certificate',
#  'Trades certificate or diploma (other than apprenticeship)',
#  'Without certificate or diploma',
#  'High school diploma or equivalent',
#  "Master's degree",
#  'University certificate or degree',
#  'Trades certificate or diploma',
#  'Without high school graduation certificate',
#  'Without degree',
#  'Registered Apprenticeship certificate',
#  'Degree in medicine, dentistry, veterinary medicine or optometry',
#  'Total - Highest certificate, diploma or degree',
#  "With bachelor's degree or higher",
# ...

# %%
'With certificate or diploma',
'University certificate or degree'
'Postsecondary certificate, diploma or degree',

# %%
educ.select(['educ','year']).where(
    educ.educ == 'No certificate, diploma or degree').distinct().toPandas().year.tolist()
# Out:
# [2006, 2011, 2016]

# %%
incTable.apply(lambda x: get_palma(x['dist'], x['tempdist']), axis=1)
# Out:
# ref_date  geo           geo_id  sex
# 2000      Calgary       394     Both sexes    2.010308
#                                 Females       1.955133
#                                 Males         1.677406
#           Edmonton      62      Both sexes    1.881632
#                                 Females       1.834967
#                                 Males         1.534666
#           Greater Sudb  2580    Both sexes    1.873238
#                                 Females       1.752994
#                                 Males         1.620759
#           Halifax       2096    Both sexes    1.572147
#                                 Females       1.588073
#                                 Males         1.523208
#           Hamilton      2608    Both sexes    1.814798
#                                 Females       1.803234
#                                 Males         1.522039
#           Kitchener-Ca  3044    Both sexes    1.602072
# ...
